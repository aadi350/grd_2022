# %%
import os
import pandas as pd
import logging
import plotly.graph_objects as go
from tqdm import tqdm

import cudf as cd
import cupy as cp

RES_PATH = '../../res/'
os.listdir(RES_PATH)

# %%
CSV_NAME = 'salinity_2.csv'
df = pd.read_csv(RES_PATH + CSV_NAME)
df.head()
# Out:
#    month        lon        lat  salinity_2  year
# 0      0 -61.067473  11.480469   35.703581  2000
# 1      1 -61.067473  11.480469   35.797483  2000
# 2      2 -61.067473  11.480469   35.778871  2000
# 3      3 -61.067473  11.480469   35.860767  2000
# 4      4 -61.067473  11.480469   35.806464  2000

# %%
df['latlon'] = df['lat'].astype(str)+df['lon'].astype(str)
df.head()
# Out:
#    month        lon        lat  salinity_2  year  \
# 0      0 -61.067473  11.480469   35.703581  2000
# 1      1 -61.067473  11.480469   35.797483  2000
# 2      2 -61.067473  11.480469   35.778871  2000
# 3      3 -61.067473  11.480469   35.860767  2000
# 4      4 -61.067473  11.480469   35.806464  2000
#
#                                  latlon
# 0  11.480469331047486-61.06747301444507
# 1  11.480469331047486-61.06747301444507
# 2  11.480469331047486-61.06747301444507
# 3  11.480469331047486-61.06747301444507
# 4  11.480469331047486-61.06747301444507

# %%
# get number of individual data streams/coordinate positions
points = df['latlon'].unique()
len(points)
# Out:
# 15861

# %%
# need to get time-series for every point as a numpy array 

data = []
data_col_name = 'salinity_2'
for p in tqdm(points):
    single_arr = ( 
        df[df.latlon == p]
        .drop(['lat', 'lon', 'latlon'], axis=1)
        .sort_values(['year', 'month'], ascending=True)
        .drop(['year','month'], axis=1)
        [data_col_name]
        .values
    )
    
    try:
        lat, lon = df[df.latlon == p]['lat'].values[0], df[df.latlon == p]['lat'].values[0]
        data.append(([lat, lon], single_arr))
    except Exception as e:
        print(p)
        print(f'lat: {df[df.latlon == p].lat.values[0]}')
        print(f'lon: {df[df.latlon == p].lon.values[0]}')
# Out:
# 100%|█████████████████████████████████████████████████| 15861/15861 [1:46:14<00:00,  2.49it/s]

# %%
import numpy as np

np.save(RES_PATH+'salinity_2.npy', data)
# Out:
# /home/aadi/miniconda3/envs/rapids-22.02/lib/python3.9/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
# sanity checking
np.load(RES_PATH+'salinity_2.npy', allow_pickle=True)
# Out:
# array([[list([11.480469331047486, 11.480469331047486]),
#         array([35.70358065, 35.79748276, 35.77887097, 35.86076667, 35.80646429,
#                35.54683333, 35.392     , 35.48148387, 35.31256667, 35.50725806,
#                35.4954    , 35.56896667, 35.84235484, 36.10642857, 36.11387097,
#                36.0734    , 35.93051613, 35.59156667, 35.262     , 34.94351613,
#                35.05762069, 35.1156129 , 35.27276667, 35.39216667, 35.66025806,
#                35.92064286, 36.07532258, 35.91      , 35.60648387, 35.23656667,
#                35.23141935, 35.37980645, 35.27586667, 35.33658065, 35.3741    ,
#                35.96683333, 35.94529032, 35.99857143, 35.987     , 35.75133333,
#                35.33251613, 34.68586667, 35.65241935, 35.42587097, 35.44083333,
#                35.61448387, 35.3771    , 35.47356667, 35.64741935, 35.84806897,
#                35.91267742, 36.1137    , 35.93796774, 35.65743333, 35.52977419,
# ...
